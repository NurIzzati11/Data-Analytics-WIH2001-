# %% [markdown]
# <a href="https://colab.research.google.com/github/NurIzzati11/Data-Analytics-WIH2001-/blob/main/Inferential_Statistics_(DA_Group).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel ('/content/cleaned_dataset.xlsx')

# %%
cormat = df.corr()
round(cormat,3)
# Out:
#                              reading_without  reading_with  numeracy_without  \
# reading_without                        1.000         0.481             0.894
# reading_with                           0.481         1.000             0.349
# numeracy_without                       0.894         0.349             1.000
# numeracy_with                          0.469         0.864             0.545
# ANAR_primary_without                   0.550         0.390             0.515
# ANAR_primary_with                     -0.293         0.393            -0.382
# ANAR_lowersecondary_without            0.550         0.390             0.515
# ANAR_lowersecondary_with              -0.293         0.393            -0.382
# ANAR_uppersecondary_without            0.550         0.390             0.515
# ANAR_uppersecondary_with              -0.293         0.393            -0.382
# OOS_primary_without                   -0.678        -0.433            -0.619
# ...

# %%
sns.heatmap(cormat)

# %% [markdown]
# Positive Correlation: (above 0.5)
#
# 1. reading_without
#
#   - numeracy_without
#   - ANAR_primary_without
#   - ANAR_lowersecondary_without
#   - ANAR_uppersecondary_without
#
# 2. reading_with
#
#   - numeracy_with

# %%
ax = sns.scatterplot(y="reading_without", x="numeracy_without", data=df)
